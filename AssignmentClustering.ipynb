# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.misc import face

# %%
f = face(gray=True)

# %%
f.shape
# Out:
# (768, 1024)

# %%
from sklearn import cluster
kmeans_cluster = cluster.KMeans(n_clusters=5,init='k-means++')
kmeans_cluster.fit(f)
cluster_centers = kmeans_cluster.cluster_centers_
cluster_labels = kmeans_cluster.labels_

# %%
cluster_centers[cluster_labels]
# Out:
# array([[123.98529412, 123.17279412, 123.16911765, ...,  87.29044118,
#          87.68382353,  87.95220588],
#        [123.98529412, 123.17279412, 123.16911765, ...,  87.29044118,
#          87.68382353,  87.95220588],
#        [123.98529412, 123.17279412, 123.16911765, ...,  87.29044118,
#          87.68382353,  87.95220588],
#        ...,
#        [115.39893617, 112.80851064, 110.32978723, ..., 105.55851064,
#         106.06914894, 106.31382979],
#        [115.39893617, 112.80851064, 110.32978723, ..., 105.55851064,
#         106.06914894, 106.31382979],
#        [115.39893617, 112.80851064, 110.32978723, ..., 105.55851064,
#         106.06914894, 106.31382979]])

# %%
plt.figure(figsize=(15,8))
plt.subplot(1,2,1)
plt.imshow(cluster_centers[cluster_labels])
plt.title('Clustered Image')
plt.subplot(1,2,2)
plt.imshow(f)
plt.title('Original Image')
# Out:
# Text(0.5, 1.0, 'Original Image')
